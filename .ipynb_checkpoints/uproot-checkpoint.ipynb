# %%
import uproot
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = uproot.open("/lustre/cms/store/user/adiflori/jpsikk_DataRunII_UltraLegacy_miniAODv2_v1_m4To6/Charmonium/crab_Charmonium_Run2018D-UL2018_MiniAODv2-v1_MINIAOD__1SKK_20220512_114449/220512_094551/0000/merged/file84.root")
print(file.classnames())
# Out:
# {'rootuple;1': 'TDirectory', 'rootuple/CandidateTree;1': 'TTree', 'rootuple/UpsTree;1': 'TTree'}

# %%
#file["rootuple"]["CandidateTree"].arrays(library="pd").to_hdf("raw/data.h5", key="candidate")
#file["rootuple"]["UpsTree"].arrays(library="pd").to_hdf("raw/data.h5", key="ups")

# %%
# ups_data = pd.read_hdf("raw/data.h5", key="ups")
# candidate_data = pd.read_hdf("raw/data.h5", key="candidate")

# %%
candidate_data = file["rootuple"]["CandidateTree"].arrays(library="pd")
candidate_data
# Out:
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
#             run      event nCandPerEvent numPrimaryVertices trigger  \
#
#
# 0        321230   31252974            17                 18       0
# 1        321230   31252974            17                 18       0
# 2        321230   31252974            17                 18       0
# 3        321230   31252974            17                 18       0
# 4        321230   31252974            17                 18       0
# ...         ...        ...           ...                ...     ...
# 3138587  324237  140894742            22                 45       0
# 3138588  324237  140894742            22                 45       0
# 3138589  324237  140894742            22                 45       0
# 3138590  324237  140894742            22                 45       0
# 3138591  324237  140894742            22                 45       0
#
#         candidate_p4                                  track1_p4  ...  \
#                   fP                               fE        fP  ...
#                   fX         fY         fZ                   fX  ...
# 0         -17.557642  -1.341422 -23.647739  29.894671 -0.712193  ...
# 1         -16.874142  -0.917237 -20.661509  27.227269 -0.744441  ...
# 2         -17.028470  -1.033802 -20.593206  27.315633 -0.898768  ...
# 3         -17.946967  -1.354190 -24.266252  30.599697 -1.101518  ...
# 4         -17.531650  -1.336938 -23.370362  29.638997 -0.712193  ...
# ...              ...        ...        ...        ...       ...  ...
# 3138587    -9.855161  10.768157  39.874534  42.725018 -0.374090  ...
# 3138588    -9.294124  10.484261  38.190015  41.062360 -0.072612  ...
# 3138589    -9.564963  10.943533  40.942233  43.751866 -0.083892  ...
# 3138590    -9.305403  10.835474  40.295628  43.105354 -0.083892  ...
# 3138591   -10.638107   9.706830  42.212100  44.953595 -0.686737  ...
#
#         track2_SDxyDsz track2_SDszDsz vChi2KalmanKK vNDFKalmanKK  \
#
#
# 0        -1.029845e-06       0.000064      0.481347          1.0
# 1         8.040199e-07       0.000179      6.025861          1.0
# 2         8.040199e-07       0.000179      0.502111          1.0
# 3        -1.029845e-06       0.000064      1.636455          1.0
# 4        -1.243304e-06       0.000062      0.007671          1.0
# ...                ...            ...           ...          ...
# 3138587  -1.013691e-05       0.001314      0.000000          0.0
# 3138588   5.172923e-06       0.000326      0.000000          0.0
# 3138589  -1.013691e-05       0.001314     75.235840          1.0
# 3138590   5.172923e-06       0.000326     15.743190          1.0
# 3138591  -4.266527e-05       0.000849      0.506048          1.0
#
#         vProbKalmanKK vChi2KinematicKK vNDFKinematicKK vProbKinematicKK  \
#
#
# 0        4.878128e-01         0.481347             1.0     4.878127e-01
# 1        1.409775e-02         6.025862             1.0     1.409774e-02
# 2        4.785742e-01         0.502111             1.0     4.785742e-01
# 3        2.008125e-01         1.636455             1.0     2.008125e-01
# 4        9.302076e-01         0.007671             1.0     9.302076e-01
# ...               ...              ...             ...              ...
# 3138587  0.000000e+00        -1.000000            -1.0    -1.000000e+00
# 3138588  0.000000e+00        43.803291             1.0     3.630939e-11
# 3138589  4.177154e-18        75.235825             1.0     4.177187e-18
# 3138590  7.254864e-05        15.743190             1.0     7.254863e-05
# 3138591  4.768547e-01         0.506048             1.0     4.768548e-01
#
#         track1_minEigen track2_minEigen
#
#
# 0          1.570557e-06   -1.696849e-07
# 1          2.921460e-06   -1.838233e-06
# 2         -2.357875e-07   -1.838233e-06
# 3         -6.691810e-08   -1.696849e-07
# 4          1.570557e-06   -6.691810e-08
# ...                 ...             ...
# 3138587    1.169150e-06   -2.305824e-05
# 3138588   -3.368846e-04   -4.123975e-05
# 3138589    2.709378e-06   -2.305824e-05
# 3138590    2.709378e-06   -4.123975e-05
# 3138591   -1.508549e-06    5.993745e-07
#
# [3138592 rows x 135 columns]

# %%
file["rootuple"]["CandidateTree"].show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# run                  | int32_t                  | AsDtype('>i4')
# event                | int32_t                  | AsDtype('>i4')
# nCandPerEvent        | int32_t                  | AsDtype('>i4')
# numPrimaryVertices   | int32_t                  | AsDtype('>i4')
# trigger              | int32_t                  | AsDtype('>i4')
# candidate_p4         | TLorentzVector           | AsStridedObjects(Model_TLor...
# track1_p4            | TLorentzVector           | AsStridedObjects(Model_TLor...
# track2_p4            | TLorentzVector           | AsStridedObjects(Model_TLor...
# ditrack_p4           | TLorentzVector           | AsStridedObjects(Model_TLor...
# dimuon_p4            | TLorentzVector           | AsStridedObjects(Model_TLor...
# muonp_p4             | TLorentzVector           | AsStridedObjects(Model_TLor...
# muonn_p4             | TLorentzVector           | AsStridedObjects(Model_TLor...
# invm1Skk             | double                   | AsDtype('>f8')
# invm2Skk             | double                   | AsDtype('>f8')
# iPVwithmuons         | int32_t                  | AsDtype('>i4')
# dimuon_vertexWeight  | int32_t                  | AsDtype('>i4')
# dimuon_vProb         | double                   | AsDtype('>f8')
# dimuon_vNChi2        | double                   | AsDtype('>f8')
# dimuon_DCA           | double                   | AsDtype('>f8')
# dimuon_ctauPV        | double                   | AsDtype('>f8')
# dimuon_ctauErrPV     | double                   | AsDtype('>f8')
# dimuon_cosAlpha      | double                   | AsDtype('>f8')
# dimuon_nSigma        | double                   | AsDtype('>f8')
# candidate_vMass      | double                   | AsDtype('>f8')
# candidate_vProb      | double                   | AsDtype('>f8')
# candidate_vChi2      | double                   | AsDtype('>f8')
# candidate_cosAlpha   | double                   | AsDtype('>f8')
# candidate_ctauPV     | double                   | AsDtype('>f8')
# candidate_ctauErrPV  | double                   | AsDtype('>f8')
# candidate_charge     | int32_t                  | AsDtype('>i4')
# candidate_lxy        | double                   | AsDtype('>f8')
# candidate_lxyErr     | double                   | AsDtype('>f8')
# candidate_lxyz       | double                   | AsDtype('>f8')
# candidate_lxyzErr    | double                   | AsDtype('>f8')
# ditrack_mass         | double                   | AsDtype('>f8')
# thePrimaryV_X        | double                   | AsDtype('>f8')
# thePrimaryV_Y        | double                   | AsDtype('>f8')
# thePrimaryV_Z        | double                   | AsDtype('>f8')
# TheDecayVertex_X     | double                   | AsDtype('>f8')
# TheDecayVertex_Y     | double                   | AsDtype('>f8')
# TheDecayVertex_Z     | double                   | AsDtype('>f8')
# thePrimaryV_2D_po... | double                   | AsDtype('>f8')
# thePrimaryV_3D_po... | double                   | AsDtype('>f8')
# TheDecayVertex_2D... | double                   | AsDtype('>f8')
# TheDecayVertex_3D... | double                   | AsDtype('>f8')
# TheVertexDistance_2D | double                   | AsDtype('>f8')
# TheVertexDistance_3D | double                   | AsDtype('>f8')
# track1_d0            | double                   | AsDtype('>f8')
# track1_d0Err         | double                   | AsDtype('>f8')
# track1_dz            | double                   | AsDtype('>f8')
# track1_dzErr         | double                   | AsDtype('>f8')
# track1_dxy           | double                   | AsDtype('>f8')
# track1_dxyErr        | double                   | AsDtype('>f8')
# track1_nvsh          | int32_t                  | AsDtype('>i4')
# track1_nvph          | int32_t                  | AsDtype('>i4')
# track1_dRdimuon      | double                   | AsDtype('>f8')
# track1_charge        | double                   | AsDtype('>f8')
# track1_PV            | int32_t                  | AsDtype('>i4')
# track1_refVtx        | int32_t                  | AsDtype('>i4')
# track1_pvAssocQ      | int32_t                  | AsDtype('>i4')
# track1_dzAssocPV     | double                   | AsDtype('>f8')
# track2_d0            | double                   | AsDtype('>f8')
# track2_d0Err         | double                   | AsDtype('>f8')
# track2_dz            | double                   | AsDtype('>f8')
# track2_dzErr         | double                   | AsDtype('>f8')
# track2_dxy           | double                   | AsDtype('>f8')
# track2_dxyErr        | double                   | AsDtype('>f8')
# track2_nvsh          | int32_t                  | AsDtype('>i4')
# track2_nvph          | int32_t                  | AsDtype('>i4')
# track2_dRdimuon      | double                   | AsDtype('>f8')
# track2_charge        | double                   | AsDtype('>f8')
# track2_PV            | int32_t                  | AsDtype('>i4')
# track2_refVtx        | int32_t                  | AsDtype('>i4')
# track2_pvAssocQ      | int32_t                  | AsDtype('>i4')
# track2_dzAssocPV     | double                   | AsDtype('>f8')
# ditrack_dRdimuon     | double                   | AsDtype('>f8')
# track1_SQopQop       | double                   | AsDtype('>f8')
# track1_SQopLam       | double                   | AsDtype('>f8')
# track1_SQopPhi       | double                   | AsDtype('>f8')
# track1_SQopDxy       | double                   | AsDtype('>f8')
# track1_SQopDsz       | double                   | AsDtype('>f8')
# track1_SLamLam       | double                   | AsDtype('>f8')
# track1_SLamPhi       | double                   | AsDtype('>f8')
# track1_SLamDxy       | double                   | AsDtype('>f8')
# track1_SLamDsz       | double                   | AsDtype('>f8')
# track1_SPhiPhi       | double                   | AsDtype('>f8')
# track1_SPhiDxy       | double                   | AsDtype('>f8')
# track1_SPhiDsz       | double                   | AsDtype('>f8')
# track1_SDxyDxy       | double                   | AsDtype('>f8')
# track1_SDxyDsz       | double                   | AsDtype('>f8')
# track1_SDszDsz       | double                   | AsDtype('>f8')
# track2_SQopQop       | double                   | AsDtype('>f8')
# track2_SQopLam       | double                   | AsDtype('>f8')
# track2_SQopPhi       | double                   | AsDtype('>f8')
# track2_SQopDxy       | double                   | AsDtype('>f8')
# track2_SQopDsz       | double                   | AsDtype('>f8')
# track2_SLamLam       | double                   | AsDtype('>f8')
# track2_SLamPhi       | double                   | AsDtype('>f8')
# track2_SLamDxy       | double                   | AsDtype('>f8')
# track2_SLamDsz       | double                   | AsDtype('>f8')
# track2_SPhiPhi       | double                   | AsDtype('>f8')
# track2_SPhiDxy       | double                   | AsDtype('>f8')
# track2_SPhiDsz       | double                   | AsDtype('>f8')
# track2_SDxyDxy       | double                   | AsDtype('>f8')
# track2_SDxyDsz       | double                   | AsDtype('>f8')
# track2_SDszDsz       | double                   | AsDtype('>f8')
# vChi2KalmanKK        | double                   | AsDtype('>f8')
# vNDFKalmanKK         | double                   | AsDtype('>f8')
# vProbKalmanKK        | double                   | AsDtype('>f8')
# vChi2KinematicKK     | double                   | AsDtype('>f8')
# vNDFKinematicKK      | double                   | AsDtype('>f8')
# vProbKinematicKK     | double                   | AsDtype('>f8')
# track1_minEigen      | double                   | AsDtype('>f8')
# track2_minEigen      | double                   | AsDtype('>f8')

# %%
cut = (candidate_data['candidate_charge'] == 0)\
    & (candidate_data['candidate_cosAlpha'] > 0.99)\
    & (candidate_data['candidate_lxy'] / candidate_data['candidate_lxyErr'] > 3.0)\
    & (candidate_data['candidate_vProb'] > 0.05)\
    & (candidate_data['ditrack_mass'] > 1.014) & (candidate_data['ditrack_mass'] < 1.024)\
    & (candidate_data['candidate_vMass'] > 5.33) & (candidate_data['candidate_vMass'] < 5.4)

# %%
candidate_data[cut]['candidate_vMass'].hist(bins=200, figsize=(15, 5), range=(5.33, 5.4))
#candidate_data[-cut]['candidate_vMass'].hist(bins=200, figsize=(15, 5), histtype="step", range=(5.25, 5.5))
# Out:
# <AxesSubplot:>

# %%
candidate_data[cut]['ditrack_mass'].hist(bins=200, figsize=(15, 5))
#candidate_data[-cut]['ditrack_mass'].hist(bins=200, figsize=(15, 5), histtype="step")
# Out:
# <AxesSubplot:>

# %%
path = "/lustre/cms/store/user/adiflori/jpsikk_DataRunII_UltraLegacy_miniAODv2_v1_m4To6/Charmonium/crab_Charmonium_Run2018D-UL2018_MiniAODv2-v1_MINIAOD__1SKK_20220512_114449/220512_094551/0000/merged/file1*.root"

# %%
data = pd.concat(uproot.iterate(
    # filename(s)
    {path : "rootuple/CandidateTree"},

    # expressions
    #["candidate_charge", "candidate_cosAlpha", "candidate_lxy", "candidate_lxyErr", "candidate_vProb", "ditrack_mass", "candidate_vMass"],

    # the all-important step_size!
    step_size="2 GB",
    library="pd"
))
# Out:
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# ...
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/new/lib/python3.8/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]

# %%
data
# Out:
#              run       event nCandPerEvent numPrimaryVertices trigger  \
#
#
# 0         324747   863257211             9                 33       0
# 1         324747   863257211             9                 33       0
# 2         324747   863257211             9                 33       0
# 3         324747   863257211             9                 33       0
# 4         324747   863257211             9                 33       0
# ...          ...         ...           ...                ...     ...
# 52173417  321475 -1167307579             4                 12       0
# 52173418  321475 -1167307579             4                 12       0
# 52173419  321475 -1167307579             4                 12       0
# 52173420  321475 -1167307579             4                 12       0
# 52173421  321475 -1167241505             1                 15       0
#
#          candidate_p4                                 track1_p4  ...  \
#                    fP                              fE        fP  ...
#                    fX        fY         fZ                   fX  ...
# 0          -11.481588  4.530073 -28.392147  31.242556 -1.386912  ...
# 1          -10.335907  3.713625 -24.511714  27.248717 -0.988740  ...
# 2           -8.828159  4.655890 -24.770920  27.333910  0.035448  ...
# 3          -11.340727  4.296695 -27.277724  30.148824 -1.077965  ...
# 4          -10.942555  3.833056 -25.695616  28.535053 -0.988740  ...
# ...               ...       ...        ...        ...       ...  ...
# 52173417     4.366822  6.690124  21.738520  23.856001  0.570734  ...
# 52173418     3.899528  8.271324  29.370979  31.157762  0.344863  ...
# 52173419     3.522908  7.982393  22.161123  24.252341  0.239841  ...
# 52173420     3.051691  7.815260  21.082170  23.354472  0.007906  ...
# 52173421    -8.155283 -0.704493  26.284206  28.062651 -0.308680  ...
#
#          track2_SDxyDsz track2_SDszDsz vChi2KalmanKK vNDFKalmanKK  \
#
#
# 0         -1.809575e-06       0.000036      0.682802          1.0
# 1         -1.189044e-06       0.000238      1.655411          1.0
# 2         -8.314293e-06       0.000925      0.034412          1.0
# 3         -5.026848e-07       0.000035      0.706724          1.0
# 4         -3.580431e-07       0.000054      4.051744          1.0
# ...                 ...            ...           ...          ...
# 52173417  -1.907637e-06       0.000148      0.173120          1.0
# 52173418   2.024699e-06       0.000362      0.027820          1.0
# 52173419   8.462844e-07       0.000191      0.000000          0.0
# 52173420  -3.000235e-06       0.000116     15.493938          1.0
# 52173421   1.557013e-06       0.000159     21.663685          1.0
#
#          vProbKalmanKK vChi2KinematicKK vNDFKinematicKK vProbKinematicKK  \
#
#
# 0             0.408623         0.682802             1.0         0.408623
# 1             0.198224         1.655411             1.0         0.198224
# 2             0.852833         0.034412             1.0         0.852833
# 3             0.400534         0.706724             1.0         0.400534
# 4             0.044126         4.051745             1.0         0.044126
# ...                ...              ...             ...              ...
# 52173417      0.677354         0.173120             1.0         0.677354
# 52173418      0.867533         0.027820             1.0         0.867533
# 52173419      0.000000        -1.000000            -1.0        -1.000000
# 52173420      0.000083        15.493940             1.0         0.000083
# 52173421      0.000003        21.663679             1.0         0.000003
#
#          track1_minEigen track2_minEigen
#
#
# 0           6.007458e-08   -1.642282e-07
# 1          -5.786225e-08   -1.777506e-08
# 2          -4.146279e-06    1.323473e-06
# 3           1.461277e-07    6.007458e-08
# 4          -5.786225e-08    1.461277e-07
# ...                  ...             ...
# 52173417   -9.120708e-06    3.989452e-06
# 52173418   -3.403788e-05   -9.989240e-06
# 52173419    2.525216e-05    2.355148e-06
# 52173420    2.355148e-06   -4.310238e-06
# 52173421   -1.422824e-04   -1.055213e-05
#
# [52173422 rows x 135 columns]

# %%
uproot.concatenate()
