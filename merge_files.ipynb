# %%
import uproot
import os
import multiprocessing
import math
import pandas as pd

path = "../data/"

def partition_helper(slice_entries, file_entries, file_curr, entry_curr):
    if slice_entries <= file_entries[file_curr] - entry_curr:
        return [file_curr, slice_entries + entry_curr]
    elif file_curr == len(file_entries) - 1:
        return [file_curr, file_entries[-1]]
    else:
        return partition_helper(slice_entries - file_entries[file_curr] + entry_curr, file_entries, file_curr + 1, 0)

def partition(files, n_processes):
    file_entries = [file.num_entries for file in files]
    slice_entries = math.ceil(sum(file_entries) / n_processes)
    slices = []
    file_start = 0
    entry_start = 0
    while not bool(slices) or slices[-1][-1] != (file_entries[-1]):
        slices.append([file_start, entry_start] + partition_helper(slice_entries, file_entries, file_start, entry_start))
        file_start = slices[-1][-2]
        entry_start = slices[-1][-1]
    return slices

def write_one_file(candidate_trees, candidate_partitions, ups_trees, ups_partitions, index, target_dir):
    candidate_data = []
    ups_data = []
    for i in range(candidate_partitions[index][0], candidate_partitions[index][2] + 1):
        candidate_data.append(candidate_trees[i].arrays(
            [key for key in candidate_trees[i].keys() if not key.endswith("_p4")],
            entry_start=candidate_partitions[index][1] if i == candidate_partitions[index][0] else None,
            entry_stop=candidate_partitions[index][3] if i == candidate_partitions[index][2] else None,
            library="pd"))
    for i in range(ups_partitions[index][0], ups_partitions[index][2] + 1):
        ups_data.append(ups_trees[i].arrays(
            [key for key in ups_trees[i].keys() if not key.endswith("_p4")],
            entry_start=ups_partitions[index][1] if i == ups_partitions[index][0] else None,
            entry_stop=ups_partitions[index][3] if i == ups_partitions[index][2] else None,
            library="pd"))
    file = uproot.recreate(target_dir + "/file" + str(index) + ".root")
    file.mkdir("rootuple")
    file["rootuple/CandidateTree"] = pd.concat(candidate_data)
    file["rootuple/UpsTree"] = pd.concat(ups_data)

def redistribute(path, n_files):
    target_dir = "../data/" + str(n_files) + "_files"
    os.mkdir(target_dir)
    candidate_trees = [uproot.open(path=path + filename + ":rootuple/CandidateTree", object_cache=None, array_cache=None) for filename in sorted(os.listdir(path))]
    candidate_partitions = partition(candidate_trees, n_files)
    ups_trees = [uproot.open(path=path + filename + ":rootuple/UpsTree", object_cache=None, array_cache=None) for filename in sorted(os.listdir(path))]
    ups_partitions = partition(ups_trees, n_files)
    result = multiprocessing.Manager().list()
    processes = []
    for i in range(n_files):
        p = multiprocessing.Process(target=write_one_file, args=[candidate_trees, candidate_partitions, ups_trees, ups_partitions, i, target_dir])
        p.start()
        processes.append(p)

    for p in processes:
        p.join()

# %%
file0 = uproot.open("../merged/file0.root:rootuple/CandidateTree")
file1 = uproot.open("../merged/file1.root:rootuple/CandidateTree")
a0 = file0.arrays(
    [key for key in file0.keys() if not key.endswith("_p4")],
    library='pd', entry_start=0, entry_stop=100)
a1 = file1.arrays(
    [key for key in file1.keys() if not key.endswith("_p4")],
    library='pd', entry_start=0, entry_stop=100)
a = pd.concat([a0, a1])
b = uproot.open("../merged/file0.root:rootuple/CandidateTree")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [123], in <cell line: 1>()
# ----> 1 file0['candidate_p4'].arrays(library='pd', entry_start=0, entry_stop=100)['pE']
#
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/core/frame.py:3504, in DataFrame.__getitem__(self, key)
#    3502 if is_single_key:
#    3503     if self.columns.nlevels > 1:
# -> 3504         return self._getitem_multilevel(key)
#    3505     indexer = self.columns.get_loc(key)
#    3506     if is_integer(indexer):
#
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/core/frame.py:3555, in DataFrame._getitem_multilevel(self, key)
#    3553 def _getitem_multilevel(self, key):
#    3554     # self.columns is a MultiIndex
# -> 3555     loc = self.columns.get_loc(key)
#    3556     if isinstance(loc, (slice, np.ndarray)):
#    3557         new_columns = self.columns[loc]
#
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2869, in MultiIndex.get_loc(self, key, method)
#    2866     return mask
#    2868 if not isinstance(key, tuple):
# -> 2869     loc = self._get_level_indexer(key, level=0)
#    2870     return _maybe_to_slice(loc)
#    2872 keylen = len(key)
#
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/core/indexes/multi.py:3222, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3218         return slice(i, j, step)
#    3220 else:
# -> 3222     idx = self._get_loc_single_level_index(level_index, key)
#    3224     if level > 0 or self._lexsort_depth == 0:
#    3225         # Desired level is not sorted
#    3226         if isinstance(idx, slice):
#    3227             # test_get_loc_partial_timestamp_multiindex
#
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2802, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2800     return -1
#    2801 else:
# -> 2802     return level_index.get_loc(key)
#
# File ~/.conda/envs/cms/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'pE'

# %%
file0.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# run                  | int32_t                  | AsDtype('>i4')
# event                | int32_t                  | AsDtype('>i4')
# nCandPerEvent        | int32_t                  | AsDtype('>i4')
# numPrimaryVertices   | int32_t                  | AsDtype('>i4')
# trigger              | int32_t                  | AsDtype('>i4')
# candidate_p4         | TLorentzVector           | AsStridedObjects(Model_TLor...
# track1_p4            | TLorentzVector           | AsStridedObjects(Model_TLor...
# track2_p4            | TLorentzVector           | AsStridedObjects(Model_TLor...
# ditrack_p4           | TLorentzVector           | AsStridedObjects(Model_TLor...
# dimuon_p4            | TLorentzVector           | AsStridedObjects(Model_TLor...
# muonp_p4             | TLorentzVector           | AsStridedObjects(Model_TLor...
# muonn_p4             | TLorentzVector           | AsStridedObjects(Model_TLor...
# invm1Skk             | double                   | AsDtype('>f8')
# invm2Skk             | double                   | AsDtype('>f8')
# iPVwithmuons         | int32_t                  | AsDtype('>i4')
# dimuon_vertexWeight  | int32_t                  | AsDtype('>i4')
# dimuon_vProb         | double                   | AsDtype('>f8')
# dimuon_vNChi2        | double                   | AsDtype('>f8')
# dimuon_DCA           | double                   | AsDtype('>f8')
# dimuon_ctauPV        | double                   | AsDtype('>f8')
# dimuon_ctauErrPV     | double                   | AsDtype('>f8')
# dimuon_cosAlpha      | double                   | AsDtype('>f8')
# dimuon_nSigma        | double                   | AsDtype('>f8')
# candidate_vMass      | double                   | AsDtype('>f8')
# candidate_vProb      | double                   | AsDtype('>f8')
# candidate_vChi2      | double                   | AsDtype('>f8')
# candidate_cosAlpha   | double                   | AsDtype('>f8')
# candidate_ctauPV     | double                   | AsDtype('>f8')
# candidate_ctauErrPV  | double                   | AsDtype('>f8')
# candidate_charge     | int32_t                  | AsDtype('>i4')
# candidate_lxy        | double                   | AsDtype('>f8')
# candidate_lxyErr     | double                   | AsDtype('>f8')
# candidate_lxyz       | double                   | AsDtype('>f8')
# candidate_lxyzErr    | double                   | AsDtype('>f8')
# ditrack_mass         | double                   | AsDtype('>f8')
# thePrimaryV_X        | double                   | AsDtype('>f8')
# thePrimaryV_Y        | double                   | AsDtype('>f8')
# thePrimaryV_Z        | double                   | AsDtype('>f8')
# TheDecayVertex_X     | double                   | AsDtype('>f8')
# TheDecayVertex_Y     | double                   | AsDtype('>f8')
# TheDecayVertex_Z     | double                   | AsDtype('>f8')
# thePrimaryV_2D_po... | double                   | AsDtype('>f8')
# thePrimaryV_3D_po... | double                   | AsDtype('>f8')
# TheDecayVertex_2D... | double                   | AsDtype('>f8')
# TheDecayVertex_3D... | double                   | AsDtype('>f8')
# TheVertexDistance_2D | double                   | AsDtype('>f8')
# TheVertexDistance_3D | double                   | AsDtype('>f8')
# track1_d0            | double                   | AsDtype('>f8')
# track1_d0Err         | double                   | AsDtype('>f8')
# track1_dz            | double                   | AsDtype('>f8')
# track1_dzErr         | double                   | AsDtype('>f8')
# track1_dxy           | double                   | AsDtype('>f8')
# track1_dxyErr        | double                   | AsDtype('>f8')
# track1_nvsh          | int32_t                  | AsDtype('>i4')
# track1_nvph          | int32_t                  | AsDtype('>i4')
# track1_dRdimuon      | double                   | AsDtype('>f8')
# track1_charge        | double                   | AsDtype('>f8')
# track1_PV            | int32_t                  | AsDtype('>i4')
# track1_refVtx        | int32_t                  | AsDtype('>i4')
# track1_pvAssocQ      | int32_t                  | AsDtype('>i4')
# track1_dzAssocPV     | double                   | AsDtype('>f8')
# track2_d0            | double                   | AsDtype('>f8')
# track2_d0Err         | double                   | AsDtype('>f8')
# track2_dz            | double                   | AsDtype('>f8')
# track2_dzErr         | double                   | AsDtype('>f8')
# track2_dxy           | double                   | AsDtype('>f8')
# track2_dxyErr        | double                   | AsDtype('>f8')
# track2_nvsh          | int32_t                  | AsDtype('>i4')
# track2_nvph          | int32_t                  | AsDtype('>i4')
# track2_dRdimuon      | double                   | AsDtype('>f8')
# track2_charge        | double                   | AsDtype('>f8')
# track2_PV            | int32_t                  | AsDtype('>i4')
# track2_refVtx        | int32_t                  | AsDtype('>i4')
# track2_pvAssocQ      | int32_t                  | AsDtype('>i4')
# track2_dzAssocPV     | double                   | AsDtype('>f8')
# ditrack_dRdimuon     | double                   | AsDtype('>f8')
# track1_SQopQop       | double                   | AsDtype('>f8')
# track1_SQopLam       | double                   | AsDtype('>f8')
# track1_SQopPhi       | double                   | AsDtype('>f8')
# track1_SQopDxy       | double                   | AsDtype('>f8')
# track1_SQopDsz       | double                   | AsDtype('>f8')
# track1_SLamLam       | double                   | AsDtype('>f8')
# track1_SLamPhi       | double                   | AsDtype('>f8')
# track1_SLamDxy       | double                   | AsDtype('>f8')
# track1_SLamDsz       | double                   | AsDtype('>f8')
# track1_SPhiPhi       | double                   | AsDtype('>f8')
# track1_SPhiDxy       | double                   | AsDtype('>f8')
# track1_SPhiDsz       | double                   | AsDtype('>f8')
# track1_SDxyDxy       | double                   | AsDtype('>f8')
# track1_SDxyDsz       | double                   | AsDtype('>f8')
# track1_SDszDsz       | double                   | AsDtype('>f8')
# track2_SQopQop       | double                   | AsDtype('>f8')
# track2_SQopLam       | double                   | AsDtype('>f8')
# track2_SQopPhi       | double                   | AsDtype('>f8')
# track2_SQopDxy       | double                   | AsDtype('>f8')
# track2_SQopDsz       | double                   | AsDtype('>f8')
# track2_SLamLam       | double                   | AsDtype('>f8')
# track2_SLamPhi       | double                   | AsDtype('>f8')
# track2_SLamDxy       | double                   | AsDtype('>f8')
# track2_SLamDsz       | double                   | AsDtype('>f8')
# track2_SPhiPhi       | double                   | AsDtype('>f8')
# track2_SPhiDxy       | double                   | AsDtype('>f8')
# track2_SPhiDsz       | double                   | AsDtype('>f8')
# track2_SDxyDxy       | double                   | AsDtype('>f8')
# track2_SDxyDsz       | double                   | AsDtype('>f8')
# track2_SDszDsz       | double                   | AsDtype('>f8')
# vChi2KalmanKK        | double                   | AsDtype('>f8')
# vNDFKalmanKK         | double                   | AsDtype('>f8')
# vProbKalmanKK        | double                   | AsDtype('>f8')
# vChi2KinematicKK     | double                   | AsDtype('>f8')
# vNDFKinematicKK      | double                   | AsDtype('>f8')
# vProbKinematicKK     | double                   | AsDtype('>f8')
# track1_minEigen      | double                   | AsDtype('>f8')
# track2_minEigen      | double                   | AsDtype('>f8')

# %%
file = uproot.recreate("../test/temp.root")
file['tree'] = a

# %%
uproot.open("../test/temp.root:tree").arrays(library='pd', entry_start=0, entry_stop=100)
# Out:
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /lustrehome/hdhoang2001/.conda/envs/cms/lib/python3.9/site-packages/uproot/interpretation/library.py:805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
#     index     run       event  nCandPerEvent  numPrimaryVertices  trigger  \
# 0       0  323778  1343450492              1                  28        0
# 1       1  323778  1343640570              7                  18        0
# 2       2  323778  1343640570              7                  18        0
# 3       3  323778  1343640570              7                  18        0
# 4       4  323778  1343640570              7                  18        0
# ..    ...     ...         ...            ...                 ...      ...
# 95     95  323778  1343831088             10                  32        0
# 96     96  323778  1343831088             10                  32        0
# 97     97  323778  1343831088             10                  32        0
# 98     98  323778  1343831088             10                  32        0
# 99     99  323778  1344142128              4                  12        0
#
#      invm1Skk   invm2Skk  iPVwithmuons  dimuon_vertexWeight  ...  \
# 0   12.138042  12.701002             0                   -1  ...
# 1   10.789125  11.352085             1                   -1  ...
# 2   11.463991  12.026951             1                   -1  ...
# 3   11.063797  11.626757             1                   -1  ...
# 4   10.802186  11.365146             1                   -1  ...
# ..        ...        ...           ...                  ...  ...
# 95  10.778086  11.341046             0                   -1  ...
# 96  10.879255  11.442215             0                   -1  ...
# 97  10.634991  11.197951             0                   -1  ...
# 98  11.453906  12.016866             0                   -1  ...
# 99  11.193448  11.756408             0                   -1  ...
#
#     track2_SDxyDsz  track2_SDszDsz  vChi2KalmanKK  vNDFKalmanKK  \
# 0     4.739249e-06        0.000186      34.981873           1.0
# 1    -8.328677e-06        0.000223       0.730809           1.0
# 2     4.808555e-07        0.000130      91.434090           1.0
# 3     4.808555e-07        0.000130      45.685955           1.0
# 4     3.620091e-06        0.000393      61.725319           1.0
# ..             ...             ...            ...           ...
# 95    3.048133e-06        0.000283       0.482558           1.0
# 96    3.048133e-06        0.000283      26.889717           1.0
# 97    3.048133e-06        0.000283       0.000000           0.0
# 98    1.729313e-06        0.000085       0.000000           0.0
# 99   -5.017224e-06        0.000256       5.905856           1.0
#
#     vProbKalmanKK  vChi2KinematicKK  vNDFKinematicKK  vProbKinematicKK  \
# 0    3.327891e-09         34.981873              1.0      3.327891e-09
# 1    3.926211e-01          0.730809              1.0      3.926211e-01
# 2    1.153717e-21         91.434090              1.0      1.153717e-21
# 3    1.388145e-11         45.685959              1.0      1.388143e-11
# 4    3.948701e-15         61.725319              1.0      3.948701e-15
# ..            ...               ...              ...               ...
# 95   4.872657e-01          0.482558              1.0      4.872657e-01
# 96   2.154019e-07         26.889748              1.0      2.153985e-07
# 97   0.000000e+00         -1.000000             -1.0     -1.000000e+00
# 98   0.000000e+00         -1.000000             -1.0     -1.000000e+00
# 99   1.509063e-02          5.905856              1.0      1.509063e-02
#
#     track1_minEigen  track2_minEigen
# 0      2.220721e-06     2.462624e-06
# 1     -4.771986e-07    -2.130578e-06
# 2     -3.622351e-06     1.286049e-06
# 3     -1.036131e-05     1.286049e-06
# 4     -1.036131e-05    -4.771986e-07
# ..              ...              ...
# 95     9.963768e-08    -9.323621e-08
# 96     7.273692e-08    -9.323621e-08
# 97     1.113631e-08    -9.323621e-08
# 98    -1.318832e-03     5.194909e-08
# 99    -1.511893e-06    -7.997042e-08
#
# [100 rows x 108 columns]
