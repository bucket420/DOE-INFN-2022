# %%
import ROOT
import GooFit as gf
import numpy as np
import matplotlib.pyplot as plt

# %%
ROOT.ROOT.EnableImplicitMT(32)

# %%
path = "/lustre/cms/store/user/adiflori/jpsikk_DataRunII_UltraLegacy_miniAODv2_v1_m4To6/Charmonium/crab_Charmonium_Run2018D-UL2018_MiniAODv2-v1_MINIAOD__1SKK_20220512_114449/220512_094551/0000/merged/file*.root"

# %%
data = ROOT.RDataFrame("rootuple/CandidateTree", path)

# %%
cut = data.Filter("candidate_charge == 0")\
          .Filter("candidate_cosAlpha > 0.99")\
          .Filter("candidate_vProb > 0.05")\
          .Filter("candidate_lxy / candidate_lxyErr > 3.0")\
          .Filter("ditrack_mass > 1.014")\
          .Filter("ditrack_mass < 1.024")\
          .Filter("candidate_vMass > 5.33")\
          .Filter("candidate_vMass < 5.4")

# %%
hist1 = cut.Histo1D(("candidate_vMass", "candidate mass", 200, 5.33, 5.4), "candidate_vMass")
canvas1 = ROOT.TCanvas()
canvas1.SetCanvasSize(1500, 500)
hist1.Draw()
canvas1.Draw()

# %%
hist2 = cut.Histo1D(("ditrack_mass", "ditrack mass", 200, 1.014, 1.024), "ditrack_mass")
canvas2 = ROOT.TCanvas()
canvas2.SetCanvasSize(1500, 500)
hist2.Draw()
canvas2.Draw()

# %%
np_array = cut.AsNumpy(["candidate_vMass"])
